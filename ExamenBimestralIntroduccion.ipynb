# %%
import pandas as pd

df = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")


print("---Analisis de datos en: IBM HR ANALYTICS EMPLOYEE ATTRITION---")


#kpi 1 la tasa de rotacion de la empresa

total_empleados = len(df)
empleados_salieron = (df['Attrition'] == 'Yes').sum()


attrition_rate = (empleados_salieron / total_empleados) * 100

print("\nKPI 1: TASA DE ROTACIÓN DE PERSONAL")
print(f"Total de empleados: {total_empleados}")
print(f"Empleados que salieron: {empleados_salieron}")
print(f"Tasa de rotacion: {attrition_rate:.2f}%")



# kpi 2 ingreso promedio mensual por departamento

print("\nIngreso Promedio Mensual por Departamento")
for departamento, ingreso in ingreso_promedio.items():
    print(f"{departamento}: ${ingreso:.2f}")


print("\nKPI 2: INGRESO PROMEDIO MENSUAL POR DEPARTAMENTO")
print(ingreso_promedio)



# kpi 3 vida-trabajo balance promedio por cargo

vidaTrabajo_promedio = (
    df.groupby('JobRole')['WorkLifeBalance'].mean().round(2).sort_values(ascending=False)

)

print("\nKPI 3: WORK-LIFE BALANCE PROMEDIO POR CARGO")
print(vidaTrabajo_promedio)



# kpi 4 brecha de estancamiento laboral

df['BrechaEstancamiento'] = (

         df['YearsInCurrentRole'] - df['YearsSinceLastPromotion']

)

brecha_promedio = round(df['BrechaEstancamiento'].mean(), 2)

print("\nKPI 4: BRECHA DE ESTANCAMIENTO LABORAL")
print(f"Brecha promedio: {brecha_promedio} años")



# interpretaciones de lo q significa cada kpi







print("--------INTERPRETACIONES DE LOS KPI PARA LA EMPRESA------------")


print(f"""
KPI 1: Rotación de la empresa: ({attrition_rate:.2f}%):
El porcentaje de empleados que abandonaron la empresa es de {attrition_rate:.2f}%. Podemos observar que una tasa elevada puede generar costos adicionales de reclutamiento y capacitación de nuevos empleados, mientras que una tasa baja nos quita esos costos.
""")

print("""
KPI 2: Ingreso Promedio Mensual por Departamento:
En este podemos ver que nos permite identificar diferencias salariales entre las áreas y evaluar la equidad interna de la empresa.
""")

print("""
KPI 3:  vida-trabajo Balance Promedio por Cargo:
Los cargos con menor puntuación de balance vida-trabajo pueden estar más expuestos al desgaste laboral y a una futura deserción del personal. Algoque no se desea.
""")

print(f"""
KPI 4: Brecha de Estancamiento Laboral ({brecha_promedio} años):
 Una brecha positiva indica que los empleados permanecen varios años en el mismo cargo sin un cargo mejor a lo largo de los años, lo que podría afectar la motivación y el desarrollo profesional.
""")
# Out:
# ---Analisis de: IBM HR ANALYTICS EMPLOYEE ATTRITION---
#
# KPI 1: TASA DE ROTACIÓN DE PERSONAL
# Total de empleados: 1470
# Empleados que salieron: 237
# Tasa de rotacion: 16.12%
#
# Ingreso Promedio Mensual por Departamento
# Human Resources: $6654.51
# Research & Development: $6281.25
# Sales: $6959.17
#
# KPI 2: INGRESO PROMEDIO MENSUAL POR DEPARTAMENTO
# Department
# Human Resources           6654.51
# Research & Development    6281.25
# Sales                     6959.17
# Name: MonthlyIncome, dtype: float64
#
# KPI 3: WORK-LIFE BALANCE PROMEDIO POR CARGO
# JobRole
# Human Resources              2.92
# Sales Representative         2.89
# Research Director            2.86
# Sales Executive              2.80
# Manager                      2.77
# Manufacturing Director       2.77
# Laboratory Technician        2.72
# Healthcare Representative    2.70
# Research Scientist           2.68
# Name: WorkLifeBalance, dtype: float64
#
# KPI 4: BRECHA DE ESTANCAMIENTO LABORAL
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-612b629a-30f5-4502-9baf-96e7b076bac7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-612b629a-30f5-4502-9baf-96e7b076bac7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
